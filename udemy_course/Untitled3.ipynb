# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas

scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('test1_secret.json', scope)
client = gspread.authorize(creds)

sheet = client.open('test2').sheet1

python_gsheets = sheet.get_all_records()
df = python_gsheets
df['2']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-7bd2f792fde0> in <module>
#      11 python_gsheets = sheet.get_all_records()
#      12 df = python_gsheets
# ---> 13 df['2']
#
# TypeError: list indices must be integers or slices, not str

# %%
dir(python_gsheets)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
df = python_gsheets

# %%
df
# Out:
# [{'suma': 'Reve Listing Tele',
#   'id_user': 31129455,
#   'cat_l2': 'Obsługa klienta / call center',
#   'wynik': 462},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 48179553,
#   'cat_l2': 'Praca za granicą',
#   'wynik': '3,280'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 16954135,
#   'cat_l2': 'Produkcja',
#   'wynik': 880},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 1682139,
#   'cat_l2': 'IT / telekomunikacja',
#   'wynik': 132},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 82021359,
#   'cat_l2': 'Przedstawiciel handlowy',
#   'wynik': '1,056'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 394505140,
#   'cat_l2': 'Administracja biurowa',
#   'wynik': '1,518'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 38776609,
#   'cat_l2': 'Administracja biurowa',
#   'wynik': 649},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 4765249,
#   'cat_l2': 'Budowa / remonty',
#   'wynik': 759},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 284366611,
#   'cat_l2': 'Produkcja',
#   'wynik': '1,338'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 12770245,
#   'cat_l2': 'Budowa / remonty',
#   'wynik': 220},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 27738689,
#   'cat_l2': 'Produkcja',
#   'wynik': 880},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 410222587,
#   'cat_l2': 'Przedstawiciel handlowy',
#   'wynik': 740},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 388916585,
#   'cat_l2': 'Produkcja',
#   'wynik': '1,150'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 284128219,
#   'cat_l2': 'Pozostałe dom i ogród',
#   'wynik': 583},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 35128699,
#   'cat_l2': 'Produkcja',
#   'wynik': 508},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 69302234,
#   'cat_l2': 'Kasjer / ekspedient',
#   'wynik': 462},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 422171049,
#   'cat_l2': 'Kierowca / kurier',
#   'wynik': 880},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 31129455,
#   'cat_l2': 'Obsługa klienta / call center',
#   'wynik': '1,297'},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 1682139,
#   'cat_l2': 'IT / telekomunikacja',
#   'wynik': 208},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 35128699,
#   'cat_l2': 'Produkcja',
#   'wynik': 119},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 4765249,
#   'cat_l2': 'Budowa / remonty',
#   'wynik': 691},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 16954135,
#   'cat_l2': 'Produkcja',
#   'wynik': 584},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 38776609,
#   'cat_l2': 'Administracja biurowa',
#   'wynik': 208},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 388916585,
#   'cat_l2': 'Produkcja',
#   'wynik': 83},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 410222587,
#   'cat_l2': 'Przedstawiciel handlowy',
#   'wynik': 102},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 82021359,
#   'cat_l2': 'Przedstawiciel handlowy',
#   'wynik': 137},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 318033496,
#   'cat_l2': 'Praca za granicą',
#   'wynik': 264},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 65754736,
#   'cat_l2': 'Hotelarstwo',
#   'wynik': 385},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 55672589,
#   'cat_l2': 'Budowa / remonty',
#   'wynik': 330},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 64589674,
#   'cat_l2': 'Hostessa',
#   'wynik': 655},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 281788574,
#   'cat_l2': 'Pozostałe oferty pracy',
#   'wynik': 715},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 16786069,
#   'cat_l2': 'Ochrona',
#   'wynik': 942},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 30677305,
#   'cat_l2': 'Pozostałe oferty pracy',
#   'wynik': 110},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 40466973,
#   'cat_l2': 'Kasjer / ekspedient',
#   'wynik': 132},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 491381,
#   'cat_l2': 'Hotelarstwo',
#   'wynik': 440},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 378967656,
#   'cat_l2': 'Przedstawiciel handlowy',
#   'wynik': 880},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 65498304,
#   'cat_l2': 'Produkcja',
#   'wynik': 662},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 22850517,
#   'cat_l2': 'Produkcja',
#   'wynik': '2,300'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 32736223,
#   'cat_l2': 'Magazynier',
#   'wynik': 451},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 39391151,
#   'cat_l2': 'Produkcja',
#   'wynik': 374},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 16301955,
#   'cat_l2': 'Pozostałe oferty pracy',
#   'wynik': 275},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 37013167,
#   'cat_l2': 'Produkcja',
#   'wynik': 374},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 37013167,
#   'cat_l2': 'Produkcja',
#   'wynik': 70},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 16301955,
#   'cat_l2': 'Pozostałe oferty pracy',
#   'wynik': 26},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 65754736,
#   'cat_l2': 'Hotelarstwo',
#   'wynik': '1,233'},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 64589674,
#   'cat_l2': 'Hostessa',
#   'wynik': 42},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 55672589,
#   'cat_l2': 'Budowa / remonty',
#   'wynik': 141},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 65498304,
#   'cat_l2': 'Produkcja',
#   'wynik': 60},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 318033496,
#   'cat_l2': 'Praca za granicą',
#   'wynik': 407},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 281788574,
#   'cat_l2': 'Pozostałe oferty pracy',
#   'wynik': 70},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 32736223,
#   'cat_l2': 'Magazynier',
#   'wynik': 576},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 16786069,
#   'cat_l2': 'Ochrona',
#   'wynik': '2,173'},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 40466973,
#   'cat_l2': 'Kasjer / ekspedient',
#   'wynik': 57},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 491381,
#   'cat_l2': 'Hotelarstwo',
#   'wynik': 476},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 73645914,
#   'cat_l2': 'Gastronomia',
#   'wynik': '1,320'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 35052979,
#   'cat_l2': 'Magazynier',
#   'wynik': 472},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 1527449,
#   'cat_l2': 'Administracja biurowa',
#   'wynik': 121},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 269239075,
#   'cat_l2': 'Produkcja',
#   'wynik': 904},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 64703880,
#   'cat_l2': 'Magazynier',
#   'wynik': '1,507'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 15522951,
#   'cat_l2': 'Budowa / remonty',
#   'wynik': 352},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 46921607,
#   'cat_l2': 'Produkcja',
#   'wynik': 264},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 47253397,
#   'cat_l2': 'Ochrona',
#   'wynik': 231},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 29914841,
#   'cat_l2': 'Kierowca / kurier',
#   'wynik': 660},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 8612917,
#   'cat_l2': 'Kasjer / ekspedient',
#   'wynik': '1,771'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 44858007,
#   'cat_l2': 'Obsługa klienta / call center',
#   'wynik': '2,838'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 34130557,
#   'cat_l2': 'Obsługa klienta / call center',
#   'wynik': '8,300'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 254633341,
#   'cat_l2': 'Kierowca / kurier',
#   'wynik': '3,280'},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 73645914,
#   'cat_l2': 'Gastronomia',
#   'wynik': 335},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 35052979,
#   'cat_l2': 'Magazynier',
#   'wynik': 203},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 47253397,
#   'cat_l2': 'Ochrona',
#   'wynik': 913},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 29914841,
#   'cat_l2': 'Kierowca / kurier',
#   'wynik': '4,943'},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 64703880,
#   'cat_l2': 'Magazynier',
#   'wynik': 593},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 269239075,
#   'cat_l2': 'Produkcja',
#   'wynik': 19},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 46921607,
#   'cat_l2': 'Produkcja',
#   'wynik': 75},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 15522951,
#   'cat_l2': 'Budowa / remonty',
#   'wynik': 235},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 1527449,
#   'cat_l2': 'Administracja biurowa',
#   'wynik': 162},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 44858007,
#   'cat_l2': 'Obsługa klienta / call center',
#   'wynik': '1,258'},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 8612917,
#   'cat_l2': 'Kasjer / ekspedient',
#   'wynik': '2,508'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 195775259,
#   'cat_l2': 'Gastronomia',
#   'wynik': 330},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 63359644,
#   'cat_l2': 'Produkcja',
#   'wynik': '1,298'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 25240719,
#   'cat_l2': 'Dostawcze i Ciężarowe',
#   'wynik': 495},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 18368869,
#   'cat_l2': 'Zdrowie i opieka',
#   'wynik': 175},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 20598883,
#   'cat_l2': 'Produkcja',
#   'wynik': '6,852'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 73794512,
#   'cat_l2': 'Hotelarstwo',
#   'wynik': '1,570'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 16246095,
#   'cat_l2': 'Praca za granicą',
#   'wynik': '2,218'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 31090371,
#   'cat_l2': 'Przedstawiciel handlowy',
#   'wynik': 198},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 28635117,
#   'cat_l2': 'Produkcja',
#   'wynik': 96},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 343088333,
#   'cat_l2': 'Produkcja',
#   'wynik': 330},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 31748401,
#   'cat_l2': 'Produkcja',
#   'wynik': 411},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 25240719,
#   'cat_l2': 'Dostawcze i Ciężarowe',
#   'wynik': 857},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 343088333,
#   'cat_l2': 'Produkcja',
#   'wynik': 233},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 73794512,
#   'cat_l2': 'Hotelarstwo',
#   'wynik': '2,077'},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 16246095,
#   'cat_l2': 'Praca za granicą',
#   'wynik': '3,046'},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 195775259,
#   'cat_l2': 'Gastronomia',
#   'wynik': 746},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 31090371,
#   'cat_l2': 'Przedstawiciel handlowy',
#   'wynik': 132},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 63359644,
#   'cat_l2': 'Produkcja',
#   'wynik': '2,828'},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 20598883,
#   'cat_l2': 'Produkcja',
#   'wynik': 325},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 18368869,
#   'cat_l2': 'Zdrowie i opieka',
#   'wynik': 149},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 31748401,
#   'cat_l2': 'Produkcja',
#   'wynik': 869},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 28635117,
#   'cat_l2': 'Produkcja',
#   'wynik': 20},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 45542309,
#   'cat_l2': 'Produkcja',
#   'wynik': '2,220'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 32466495,
#   'cat_l2': 'Pozostałe oferty pracy',
#   'wynik': 616},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 84537921,
#   'cat_l2': 'Produkcja',
#   'wynik': '1,456'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 142355985,
#   'cat_l2': 'Obsługa klienta / call center',
#   'wynik': 462},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 17597999,
#   'cat_l2': 'Produkcja',
#   'wynik': '2,365'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 77490169,
#   'cat_l2': 'Hostessa',
#   'wynik': 115},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 79795737,
#   'cat_l2': 'Kasjer / ekspedient',
#   'wynik': 649},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 6206675,
#   'cat_l2': 'Sprzątanie',
#   'wynik': 341},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 19751865,
#   'cat_l2': 'Kasjer / ekspedient',
#   'wynik': 198},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 74965896,
#   'cat_l2': 'Finanse / księgowość',
#   'wynik': 636},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 23436139,
#   'cat_l2': 'Magazynier',
#   'wynik': '1,309'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 39098895,
#   'cat_l2': 'Magazynier',
#   'wynik': '2,641'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 28570733,
#   'cat_l2': 'Przedstawiciel handlowy',
#   'wynik': 462},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 84400821,
#   'cat_l2': 'Pozostałe oferty pracy',
#   'wynik': 327},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 43381711,
#   'cat_l2': 'Mechanik / blacharz / lakiernik',
#   'wynik': 420},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 22503111,
#   'cat_l2': 'Produkcja',
#   'wynik': '2,560'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 43582585,
#   'cat_l2': 'Kierowca / kurier',
#   'wynik': '2,447'},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 43381711,
#   'cat_l2': 'Mechanik / blacharz / lakiernik',
#   'wynik': 449},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 43582585,
#   'cat_l2': 'Kierowca / kurier',
#   'wynik': 801},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 22503111,
#   'cat_l2': 'Produkcja',
#   'wynik': 53},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 64577742,
#   'cat_l2': 'Produkcja',
#   'wynik': 28},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 74965896,
#   'cat_l2': 'Finanse / księgowość',
#   'wynik': 128},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 142355985,
#   'cat_l2': 'Obsługa klienta / call center',
#   'wynik': 127},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 84537921,
#   'cat_l2': 'Produkcja',
#   'wynik': '1,540'},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 6206675,
#   'cat_l2': 'Sprzątanie',
#   'wynik': 264},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 19751865,
#   'cat_l2': 'Kasjer / ekspedient',
#   'wynik': 114},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 39098895,
#   'cat_l2': 'Magazynier',
#   'wynik': 250},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 84400821,
#   'cat_l2': 'Pozostałe oferty pracy',
#   'wynik': 592},
#  {'suma': 'Reve Vas Tele',
#   'id_user': 28570733,
#   'cat_l2': 'Przedstawiciel handlowy',
#   'wynik': 243},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 43864327,
#   'cat_l2': 'Kasjer / ekspedient',
#   'wynik': '1,150'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 4184527,
#   'cat_l2': 'Kasjer / ekspedient',
#   'wynik': '1,216'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 83558149,
#   'cat_l2': 'Praca za granicą',
#   'wynik': 880},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 271998325,
#   'cat_l2': 'Obsługa klienta / call center',
#   'wynik': 825},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 9624177,
#   'cat_l2': 'Gastronomia',
#   'wynik': 94},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 14717045,
#   'cat_l2': 'Kierowca / kurier',
#   'wynik': '2,188'},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 378880394,
#   'cat_l2': 'Produkcja',
#   'wynik': 260},
#  {'suma': 'Reve Listing Tele',
#   'id_user': 36068133,
#   'cat_l2': 'Przedstawiciel handlowy',
#   'wynik': '1,954'}]
